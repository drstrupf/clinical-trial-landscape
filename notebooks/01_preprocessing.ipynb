# %% [markdown]
# # Preprocess clinical trial data from clinicaltrials.gov
# Raw data were exported as .csv, and some fields contain lists (e.g. the trial sites). Here we create a long-form dataset to simplify further analysis. Long-form means that if e.g. a trial has sites in more than one country, there will be a row for each country separately.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext blackcellmagic

# %%
import pandas as pd

# %%
raw_trial_data = pd.read_csv("data/source/clinicaltrials//clinicaltrials_allMS_trials.csv")

# %%
raw_trial_data.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 2  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 3  NCT05090033  Characterizing the Use of Ofatumumab in a Real...
# 4  NCT00883337  A Study Comparing the Effectiveness and Safety...
#
#                                            Study URL Study Status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 2  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 3  https://beta.clinicaltrials.gov/study/NCT05090033   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT00883337    COMPLETED
#
#                                           Conditions  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 1                                 Multiple Sclerosis
# 2  Multiple Sclerosis, Chronic Progressive|High-I...
# 3                       Relapsing Multiple Sclerosis
# 4                                 Multiple Sclerosis
#
#                                Interventions  \
# 0                    OTHER: No Interventions
# 1                          DRUG: Natalizumab
# 2           BEHAVIORAL: HIIT|BEHAVIORAL: MCT
# 3                          OTHER: ofatumumab
# 4  DRUG: Interferon β-1a|DRUG: Teriflunomide
#
#                             Sponsor                  Collaborators  Sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1     University Hospital, Toulouse                            NaN  ALL
# 2                     Klinik Valens                            NaN  ALL
# 3          Novartis Pharmaceuticals                            NaN  ALL
# 4                            Sanofi                            NaN  ALL
#
#                   Age  Phases  Enrollment Funder Type      Study Type  \
# 0  ADULT, OLDER_ADULT     NaN      1500.0       OTHER   OBSERVATIONAL
# 1               ADULT  PHASE4       300.0       OTHER  INTERVENTIONAL
# 2  ADULT, OLDER_ADULT     NaN        30.0       OTHER  INTERVENTIONAL
# 3  ADULT, OLDER_ADULT     NaN      3500.0    INDUSTRY   OBSERVATIONAL
# 4  ADULT, OLDER_ADULT  PHASE3       324.0    INDUSTRY  INTERVENTIONAL
#
#                                         Study Design  Start Date  \
# 0          Observational Model: |Time Perspective: p  2020-06-29
# 1  Allocation: NA|Intervention Model: SINGLE_GROU...     2009-06
# 2  Allocation: RANDOMIZED|Intervention Model: PAR...  2022-10-01
# 3          Observational Model: |Time Perspective: p  2022-12-08
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...     2009-04
#
#   Primary Completion Date Completion Date  \
# 0              2021-01-30      2021-07-30
# 1                 2011-02         2011-03
# 2              2023-04-01      2023-04-01
# 3              2025-06-30      2025-06-30
# 4                 2011-09         2015-05
#
#                                            Locations
# 0  Advanced Neurosciences Institute, Franklin, Te...
# 1  service de neurologie, hôpital Purpan, Toulous...
# 2  Klinik Valens, Valens rehabilitation clinic, V...
# 3  Novartis Investigative Site, Concord, New Sout...
# 4  Investigational Site Number 056003, Bruxelles,...

# %% [markdown]
# ## Create a base dataframe with trial ID, title, URL, and status

# %%
raw_trial_data = raw_trial_data.rename(columns={"NCT Number": "nct_number"})

# %% [markdown]
# Only one row per trial?

# %%
len(raw_trial_data) == len(raw_trial_data["nct_number"].drop_duplicates())
# Out:
# True

# %%
trial_data = (
    raw_trial_data[["nct_number", "Study Title", "Study URL", "Study Status"]]
    .rename(
        columns={
            "Study Title": "study_title",
            "Study URL": "study_url",
            "Study Status": "study_status",
        }
    )
    .copy()
)

# %%
trial_data.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 2  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 3  NCT05090033  Characterizing the Use of Ofatumumab in a Real...
# 4  NCT00883337  A Study Comparing the Effectiveness and Safety...
#
#                                            study_url study_status
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 2  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 3  https://beta.clinicaltrials.gov/study/NCT05090033   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT00883337    COMPLETED

# %% [markdown]
# ## Explode the listed conditions, export, filter manually, import filtered list, and filter data
# The search function on clinicaltrials.gov might yield false positives when searching for common abbreviations related to MS. We thus list all mentioned conditions, then filter them manually. The filtered list is then imported again, and only trials where at least one of these conditions is mentioned are retained in the data set.

# %% [markdown]
# ### Explode and export
# If a trial includes multiple conditions, they are provided as a pipe-separated list. We split this list, and write a row for each list item. Then we remove duplicates and export the conditions for manual filtering.

# %%
conditions = raw_trial_data[["nct_number", "Conditions"]].copy()

# %%
conditions["condition"] = conditions["Conditions"].str.split("|")
conditions = conditions.explode("condition")

# %%
conditions.head()
# Out:
#     nct_number                                         Conditions  \
# 0  NCT04447937  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 0  NCT04447937  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 0  NCT04447937  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 0  NCT04447937  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 1  NCT00942214                                 Multiple Sclerosis
#
#                condition
# 0     Multiple Sclerosis
# 0  Hypogammaglobulinemia
# 0       Immunodeficiency
# 0   Infection, Bacterial
# 1     Multiple Sclerosis

# %%
conditions_for_export = (
    conditions[["condition"]].drop_duplicates().sort_values("condition")
)

# %%
# safety switch
polse

# %%
with pd.ExcelWriter("data/manual/clinicaltrials/all_conditions.xlsx") as writer:
    conditions_for_export.to_excel(writer, index=False)

# %% [markdown]
# ### Import and filter
# Import the filtered list of conditions, then retain only those trials with at least one of those conditions.

# %%
ms_conditions = pd.read_excel("data/manual/clinicaltrials/conditions_list_filtered.xlsx")

# %%
ms_conditions.head()
# Out:
#                                            condition   tag
# 0    Active Secondary Progressive Multiple Sclerosis  SPMS
# 1               Acute Disseminated Encephalomyelitis    MS
# 2  Acute Exacerbation of Remitting Relapsing Mult...  RRMS
# 3                        Advanced Multiple Sclerosis    MS
# 4                       Advancing Multiple Sclerosis    MS

# %% [markdown]
# For filtering, we use an inner join, since we only consider MS trials.

# %%
ms_trials = pd.merge(
    left=conditions, right=ms_conditions, on="condition", how="inner"
)

# %% [markdown]
# ### Drop the single-condition column, just keep the condition categories
# This is to reduce the size of the dataset; we don't need resolution beyond the categories.

# %%
ms_trials = (
    ms_trials[["nct_number", "Conditions", "tag"]]
    .drop_duplicates()
    .rename(columns={"Conditions": "conditions", "tag": "condition_category"})
    .copy()
)

# %%
ms_trials
# Out:
#        nct_number                                         conditions  \
# 0     NCT04447937  Multiple Sclerosis|Hypogammaglobulinemia|Immun...
# 1     NCT00942214                                 Multiple Sclerosis
# 2     NCT00883337                                 Multiple Sclerosis
# 3     NCT01018537                                 Multiple Sclerosis
# 4     NCT04132037                                 Multiple Sclerosis
# ...           ...                                                ...
# 2995  NCT03636789  Radiologically Isolated Syndrome (RIS)|Multipl...
# 2996  NCT05437276  Gait Impairment Due to Mild/Moderate Multiple ...
# 2997  NCT01865357  Clinically Isolated Demyelinating Syndromes|Mu...
# 2998  NCT04369898                                Multiple Sclerosis)
# 2999  NCT05341895  Individuals With Multiple Sclerosis|With Ataxi...
#
#      condition_category
# 0                    MS
# 1                    MS
# 2                    MS
# 3                    MS
# 4                    MS
# ...                 ...
# 2995                RIS
# 2996                 MS
# 2997                CIS
# 2998                 MS
# 2999                 MS
#
# [2975 rows x 3 columns]

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(left=trial_data, right=ms_trials, on="nct_number", how="inner")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 2  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 3  NCT05090033  Characterizing the Use of Ofatumumab in a Real...
# 4  NCT00883337  A Study Comparing the Effectiveness and Safety...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 2  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 3  https://beta.clinicaltrials.gov/study/NCT05090033   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT00883337    COMPLETED
#
#                                           conditions condition_category
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1                                 Multiple Sclerosis                 MS
# 2  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 3                       Relapsing Multiple Sclerosis                RMS
# 4                                 Multiple Sclerosis                 MS

# %%
len(ms_trials["nct_number"].drop_duplicates())
# Out:
# 2711

# %% [markdown]
# We have identified 2711 MS trials.

# %% [markdown]
# ## Interventions
# Convert the intervention lists to long-form. If a trial includes more than one intervention, they are provided in a pipe-separated list. We will create one row per intervention.

# %%
interventions = raw_trial_data[["nct_number", "Interventions"]].copy()

# %%
interventions["intervention"] = interventions["Interventions"].str.split("|")
interventions = interventions.explode("intervention")

# %%
interventions.head()
# Out:
#     nct_number                     Interventions             intervention
# 0  NCT04447937           OTHER: No Interventions  OTHER: No Interventions
# 1  NCT00942214                 DRUG: Natalizumab        DRUG: Natalizumab
# 2  NCT05562414  BEHAVIORAL: HIIT|BEHAVIORAL: MCT         BEHAVIORAL: HIIT
# 2  NCT05562414  BEHAVIORAL: HIIT|BEHAVIORAL: MCT          BEHAVIORAL: MCT
# 3  NCT05090033                 OTHER: ofatumumab        OTHER: ofatumumab

# %% [markdown]
# Are there trials where intervention is not specified?

# %%
len(interventions[interventions["Interventions"].isna()]) > 0
# Out:
# True

# %% [markdown]
# Drop trials where intervention is not specified. We will keep them in our final dataset, though (see below, where we used a left join to add the intervention data to the base dataframe).

# %%
interventions = interventions[~interventions["Interventions"].isna()].copy()

# %% [markdown]
# ### Keep the intervention type only
# Again, intervention type level information is sufficient for our analysis.

# %%
interventions["intervention_type"] = (
    interventions["intervention"].str.split(":").str[0]
)

# %%
interventions.head()
# Out:
#     nct_number                     Interventions             intervention  \
# 0  NCT04447937           OTHER: No Interventions  OTHER: No Interventions
# 1  NCT00942214                 DRUG: Natalizumab        DRUG: Natalizumab
# 2  NCT05562414  BEHAVIORAL: HIIT|BEHAVIORAL: MCT         BEHAVIORAL: HIIT
# 2  NCT05562414  BEHAVIORAL: HIIT|BEHAVIORAL: MCT          BEHAVIORAL: MCT
# 3  NCT05090033                 OTHER: ofatumumab        OTHER: ofatumumab
#
#   intervention_type
# 0             OTHER
# 1              DRUG
# 2        BEHAVIORAL
# 2        BEHAVIORAL
# 3             OTHER

# %%
interventions = (
    interventions[["nct_number", "Interventions", "intervention_type"]]
    .rename(columns={"Interventions": "interventions"})
    .drop_duplicates()
    .copy()
)

# %%
interventions.head()
# Out:
#     nct_number                              interventions intervention_type
# 0  NCT04447937                    OTHER: No Interventions             OTHER
# 1  NCT00942214                          DRUG: Natalizumab              DRUG
# 2  NCT05562414           BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 3  NCT05090033                          OTHER: ofatumumab             OTHER
# 4  NCT00883337  DRUG: Interferon β-1a|DRUG: Teriflunomide              DRUG

# %% [markdown]
# ### Merge with base dataframe
# We use a left join here, i.e. we keep trials where intervention is not specified in the overall dataset.

# %%
ms_trials = pd.merge(left=ms_trials, right=interventions, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 2  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 3  NCT05090033  Characterizing the Use of Ofatumumab in a Real...
# 4  NCT00883337  A Study Comparing the Effectiveness and Safety...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 2  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 3  https://beta.clinicaltrials.gov/study/NCT05090033   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT00883337    COMPLETED
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1                                 Multiple Sclerosis                 MS
# 2  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 3                       Relapsing Multiple Sclerosis                RMS
# 4                                 Multiple Sclerosis                 MS
#
#                                interventions intervention_type
# 0                    OTHER: No Interventions             OTHER
# 1                          DRUG: Natalizumab              DRUG
# 2           BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 3                          OTHER: ofatumumab             OTHER
# 4  DRUG: Interferon β-1a|DRUG: Teriflunomide              DRUG

# %% [markdown]
# ## Sponsors and collaborators

# %% [markdown]
# ### Sponsors

# %% [markdown]
# Does the 'Sponsor' column contain a list?

# %%
raw_trial_data[raw_trial_data["Sponsor"].str.contains(r"|", regex=False)][["Sponsor"]].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Sponsor]
# Index: []

# %% [markdown]
# -> each trial has only one sponsor listed (and no trial has no sponsor listed, otherwise the above would fail).

# %% [markdown]
# ### Collaborators

# %% [markdown]
# The 'Collaborators' column contains a list; however, this is beyond the resolution we need, so we keep this column as-is for now.

# %%
sponsors_collaborators = (
    raw_trial_data[["nct_number", "Sponsor", "Collaborators"]]
    .rename(columns={"Sponsor": "sponsor", "Collaborators": "collaborators"})
    .drop_duplicates()
    .copy()
)

# %%
sponsors_collaborators
# Out:
#        nct_number                           sponsor  \
# 0     NCT04447937  Advanced Neurosciences Institute
# 1     NCT00942214     University Hospital, Toulouse
# 2     NCT05562414                     Klinik Valens
# 3     NCT05090033          Novartis Pharmaceuticals
# 4     NCT00883337                            Sanofi
# ...           ...                               ...
# 2959  NCT02451696                NYU Langone Health
# 2960  NCT01191996         Innate Immunotherapeutics
# 2961  NCT03826095              Hacettepe University
# 2962  NCT05341895                  Firat University
# 2963  NCT03458169  Clinique Romande de Readaptation
#
#                                           collaborators
# 0                         Novel Pharmaceutics Institute
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2959                                                NaN
# 2960  Primorus Clinical Trials|National Multiple Scl...
# 2961                        KARMUTLU|MATUNCER|EÇKÜTÜKÇÜ
# 2962                                                NaN
# 2963                                                NaN
#
# [2964 rows x 3 columns]

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(
    left=ms_trials, right=sponsors_collaborators, on="nct_number", how="left"
)

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 2  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 3  NCT05090033  Characterizing the Use of Ofatumumab in a Real...
# 4  NCT00883337  A Study Comparing the Effectiveness and Safety...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 2  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 3  https://beta.clinicaltrials.gov/study/NCT05090033   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT00883337    COMPLETED
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1                                 Multiple Sclerosis                 MS
# 2  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 3                       Relapsing Multiple Sclerosis                RMS
# 4                                 Multiple Sclerosis                 MS
#
#                                interventions intervention_type  \
# 0                    OTHER: No Interventions             OTHER
# 1                          DRUG: Natalizumab              DRUG
# 2           BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 3                          OTHER: ofatumumab             OTHER
# 4  DRUG: Interferon β-1a|DRUG: Teriflunomide              DRUG
#
#                             sponsor                  collaborators
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute
# 1     University Hospital, Toulouse                            NaN
# 2                     Klinik Valens                            NaN
# 3          Novartis Pharmaceuticals                            NaN
# 4                            Sanofi                            NaN

# %% [markdown]
# ## Age and sex

# %% [markdown]
# ### Sex

# %%
raw_trial_data[["Sex"]].drop_duplicates()
# Out:
#        Sex
# 0      ALL
# 10  FEMALE
# 31    MALE
# 50     NaN

# %% [markdown]
# Leave as-is.

# %% [markdown]
# ### Age

# %%
raw_trial_data[["Age"]].drop_duplicates()
# Out:
#                             Age
# 0            ADULT, OLDER_ADULT
# 1                         ADULT
# 10    CHILD, ADULT, OLDER_ADULT
# 16                 CHILD, ADULT
# 69                        CHILD
# 1605                OLDER_ADULT

# %% [markdown]
# Split to long-form.

# %%
raw_trial_data[raw_trial_data["Age"].isna()]
# Out:
# Empty DataFrame
# Columns: [nct_number, Study Title, Study URL, Study Status, Conditions, Interventions, Sponsor, Collaborators, Sex, Age, Phases, Enrollment, Funder Type, Study Type, Study Design, Start Date, Primary Completion Date, Completion Date, Locations]
# Index: []

# %%
age_sex = raw_trial_data[["nct_number", "Sex", "Age"]].drop_duplicates().copy()

# %%
age_sex["age_category"] = age_sex["Age"].str.split(",")
age_sex = age_sex.explode("age_category")

# %%
age_sex = age_sex.rename(columns={"Sex": "sex", "Age": "age"})

# %%
age_sex
# Out:
#        nct_number  sex                        age  age_category
# 0     NCT04447937  ALL         ADULT, OLDER_ADULT         ADULT
# 0     NCT04447937  ALL         ADULT, OLDER_ADULT   OLDER_ADULT
# 1     NCT00942214  ALL                      ADULT         ADULT
# 2     NCT05562414  ALL         ADULT, OLDER_ADULT         ADULT
# 2     NCT05562414  ALL         ADULT, OLDER_ADULT   OLDER_ADULT
# ...           ...  ...                        ...           ...
# 2962  NCT05341895  ALL         ADULT, OLDER_ADULT         ADULT
# 2962  NCT05341895  ALL         ADULT, OLDER_ADULT   OLDER_ADULT
# 2963  NCT03458169  ALL  CHILD, ADULT, OLDER_ADULT         CHILD
# 2963  NCT03458169  ALL  CHILD, ADULT, OLDER_ADULT         ADULT
# 2963  NCT03458169  ALL  CHILD, ADULT, OLDER_ADULT   OLDER_ADULT
#
# [5229 rows x 4 columns]

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(left=ms_trials, right=age_sex, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 2     University Hospital, Toulouse                            NaN  ALL
# 3                     Klinik Valens                            NaN  ALL
# 4                     Klinik Valens                            NaN  ALL
#
#                   age  age_category
# 0  ADULT, OLDER_ADULT         ADULT
# 1  ADULT, OLDER_ADULT   OLDER_ADULT
# 2               ADULT         ADULT
# 3  ADULT, OLDER_ADULT         ADULT
# 4  ADULT, OLDER_ADULT   OLDER_ADULT

# %% [markdown]
# ## Phases

# %%
raw_trial_data[["Phases"]].drop_duplicates()
# Out:
#            Phases
# 0             NaN
# 1          PHASE4
# 4          PHASE3
# 6          PHASE2
# 12         PHASE1
# 14  PHASE2|PHASE3
# 40  PHASE1|PHASE2
# 46   EARLY_PHASE1

# %% [markdown]
# Split the phase list; trials with more than one phase will be counted for each phase separately.

# %%
phases = raw_trial_data[["nct_number", "Phases"]].drop_duplicates().copy()
phases["phase"] = phases["Phases"].str.split("|")
phases = phases.explode("phase")
phases = phases.rename(columns={"Phases": "phases"})

# %%
phases
# Out:
#        nct_number         phases   phase
# 0     NCT04447937            NaN     NaN
# 1     NCT00942214         PHASE4  PHASE4
# 2     NCT05562414            NaN     NaN
# 3     NCT05090033            NaN     NaN
# 4     NCT00883337         PHASE3  PHASE3
# ...           ...            ...     ...
# 2960  NCT01191996  PHASE1|PHASE2  PHASE1
# 2960  NCT01191996  PHASE1|PHASE2  PHASE2
# 2961  NCT03826095            NaN     NaN
# 2962  NCT05341895            NaN     NaN
# 2963  NCT03458169            NaN     NaN
#
# [3115 rows x 3 columns]

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(left=ms_trials, right=phases, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 2     University Hospital, Toulouse                            NaN  ALL
# 3                     Klinik Valens                            NaN  ALL
# 4                     Klinik Valens                            NaN  ALL
#
#                   age  age_category  phases   phase
# 0  ADULT, OLDER_ADULT         ADULT     NaN     NaN
# 1  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN
# 2               ADULT         ADULT  PHASE4  PHASE4
# 3  ADULT, OLDER_ADULT         ADULT     NaN     NaN
# 4  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN

# %% [markdown]
# ## Enrollment

# %%
len(raw_trial_data[raw_trial_data["Enrollment"].isna()].drop_duplicates())
# Out:
# 13

# %% [markdown]
# A few trials don't specify enrollment; what about the rest?

# %%
enrollment_notnan = raw_trial_data[~raw_trial_data["Enrollment"].isna()].copy()
enrollment_notnan["enrollment_int"] = enrollment_notnan["Enrollment"].astype(int)

# %% [markdown]
# The rest can be converted to integer if required; we leave this for now, as enrollment is trial-level anyway (no country-level or site-level resolution) and we thus won't analyze it further.

# %% [markdown]
# ### Merge with base dataframe

# %%
enrollment = (
    raw_trial_data[["nct_number", "Enrollment"]]
    .rename(columns={"Enrollment": "enrollment"})
    .drop_duplicates()
    .copy()
)

# %%
ms_trials = pd.merge(left=ms_trials, right=enrollment, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 2     University Hospital, Toulouse                            NaN  ALL
# 3                     Klinik Valens                            NaN  ALL
# 4                     Klinik Valens                            NaN  ALL
#
#                   age  age_category  phases   phase  enrollment
# 0  ADULT, OLDER_ADULT         ADULT     NaN     NaN      1500.0
# 1  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN      1500.0
# 2               ADULT         ADULT  PHASE4  PHASE4       300.0
# 3  ADULT, OLDER_ADULT         ADULT     NaN     NaN        30.0
# 4  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN        30.0

# %% [markdown]
# ## Funder type and study type

# %% [markdown]
# ### Funder type

# %%
raw_trial_data[["Funder Type"]].drop_duplicates()
# Out:
#     Funder Type
# 0         OTHER
# 3      INDUSTRY
# 26          NIH
# 29    OTHER_GOV
# 176     NETWORK
# 372       INDIV
# 424         FED

# %%
raw_trial_data[raw_trial_data["Funder Type"].isna()]
# Out:
# Empty DataFrame
# Columns: [nct_number, Study Title, Study URL, Study Status, Conditions, Interventions, Sponsor, Collaborators, Sex, Age, Phases, Enrollment, Funder Type, Study Type, Study Design, Start Date, Primary Completion Date, Completion Date, Locations]
# Index: []

# %% [markdown]
# This is fine, no processing required.

# %% [markdown]
# ### Study type

# %%
raw_trial_data[["Study Type"]].drop_duplicates()
# Out:
#            Study Type
# 0       OBSERVATIONAL
# 1      INTERVENTIONAL
# 1268  EXPANDED_ACCESS

# %%
raw_trial_data[raw_trial_data["Study Type"].isna()]
# Out:
# Empty DataFrame
# Columns: [nct_number, Study Title, Study URL, Study Status, Conditions, Interventions, Sponsor, Collaborators, Sex, Age, Phases, Enrollment, Funder Type, Study Type, Study Design, Start Date, Primary Completion Date, Completion Date, Locations]
# Index: []

# %% [markdown]
# This is fine, no processing required.

# %% [markdown]
# ### Merge with base dataframe

# %%
funder_study_type = (
    raw_trial_data[["nct_number", "Funder Type", "Study Type"]]
    .rename(columns={"Funder Type": "funder_type", "Study Type": "study_type"})
    .drop_duplicates()
    .copy()
)

# %%
ms_trials = pd.merge(left=ms_trials, right=funder_study_type, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 2     University Hospital, Toulouse                            NaN  ALL
# 3                     Klinik Valens                            NaN  ALL
# 4                     Klinik Valens                            NaN  ALL
#
#                   age  age_category  phases   phase  enrollment funder_type  \
# 0  ADULT, OLDER_ADULT         ADULT     NaN     NaN      1500.0       OTHER
# 1  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN      1500.0       OTHER
# 2               ADULT         ADULT  PHASE4  PHASE4       300.0       OTHER
# 3  ADULT, OLDER_ADULT         ADULT     NaN     NaN        30.0       OTHER
# 4  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN        30.0       OTHER
#
#        study_type
# 0   OBSERVATIONAL
# 1   OBSERVATIONAL
# 2  INTERVENTIONAL
# 3  INTERVENTIONAL
# 4  INTERVENTIONAL

# %% [markdown]
# ## Study design

# %%
design = (
    raw_trial_data[["nct_number", "Study Design"]]
    .rename(columns={"Study Design": "study_design"})
    .drop_duplicates()
    .copy()
)

# %%
design
# Out:
#        nct_number                                       study_design
# 0     NCT04447937          Observational Model: |Time Perspective: p
# 1     NCT00942214  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2     NCT05562414  Allocation: RANDOMIZED|Intervention Model: PAR...
# 3     NCT05090033          Observational Model: |Time Perspective: p
# 4     NCT00883337  Allocation: RANDOMIZED|Intervention Model: PAR...
# ...           ...                                                ...
# 2959  NCT02451696  Allocation: NON_RANDOMIZED|Intervention Model:...
# 2960  NCT01191996  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2961  NCT03826095          Observational Model: |Time Perspective: p
# 2962  NCT05341895  Allocation: NON_RANDOMIZED|Intervention Model:...
# 2963  NCT03458169  Allocation: NA|Intervention Model: SINGLE_GROU...
#
# [2964 rows x 2 columns]

# %% [markdown]
# ### Extract the primary purpose

# %%
primary_purpose = design.copy()
primary_purpose["primary_purpose"] = primary_purpose["study_design"].str.split(
    "|"
)
primary_purpose = primary_purpose.explode("primary_purpose")

# %% [markdown]
# Drop NaNs.

# %%
primary_purpose = primary_purpose[
    ~primary_purpose["primary_purpose"].isna()
].copy()

# %% [markdown]
# Keep on 'Primary Purpose' and drop the rest.

# %%
primary_purpose = primary_purpose[
    primary_purpose["primary_purpose"].str.startswith("Primary Purpose")
].copy()

# %%
primary_purpose
# Out:
#        nct_number                                       study_design  \
# 1     NCT00942214  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2     NCT05562414  Allocation: RANDOMIZED|Intervention Model: PAR...
# 4     NCT00883337  Allocation: RANDOMIZED|Intervention Model: PAR...
# 6     NCT03249714  Allocation: RANDOMIZED|Intervention Model: PAR...
# 9     NCT05809414  Allocation: RANDOMIZED|Intervention Model: CRO...
# ...           ...                                                ...
# 2955  NCT01845896  Allocation: RANDOMIZED|Intervention Model: PAR...
# 2959  NCT02451696  Allocation: NON_RANDOMIZED|Intervention Model:...
# 2960  NCT01191996  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2962  NCT05341895  Allocation: NON_RANDOMIZED|Intervention Model:...
# 2963  NCT03458169  Allocation: NA|Intervention Model: SINGLE_GROU...
#
#                   primary_purpose
# 1     Primary Purpose: DIAGNOSTIC
# 2      Primary Purpose: TREATMENT
# 4      Primary Purpose: TREATMENT
# 6      Primary Purpose: TREATMENT
# 9      Primary Purpose: TREATMENT
# ...                           ...
# 2955   Primary Purpose: TREATMENT
# 2959   Primary Purpose: TREATMENT
# 2960   Primary Purpose: TREATMENT
# 2962       Primary Purpose: OTHER
# 2963       Primary Purpose: OTHER
#
# [2124 rows x 3 columns]

# %% [markdown]
# Clean up.

# %%
primary_purpose["primary_purpose"] = primary_purpose[
    "primary_purpose"
].str.replace("Primary Purpose: ", "")

# %%
primary_purpose.head()
# Out:
#     nct_number                                       study_design  \
# 1  NCT00942214  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2  NCT05562414  Allocation: RANDOMIZED|Intervention Model: PAR...
# 4  NCT00883337  Allocation: RANDOMIZED|Intervention Model: PAR...
# 6  NCT03249714  Allocation: RANDOMIZED|Intervention Model: PAR...
# 9  NCT05809414  Allocation: RANDOMIZED|Intervention Model: CRO...
#
#   primary_purpose
# 1      DIAGNOSTIC
# 2       TREATMENT
# 4       TREATMENT
# 6       TREATMENT
# 9       TREATMENT

# %% [markdown]
# Sanity check: only one primary purpose per trial?

# %%
primary_purpose.groupby(
    ["nct_number", "study_design"]
).count().reset_index().sort_values("primary_purpose", ascending=False).head()
# Out:
#        nct_number                                       study_design  \
# 0     NCT00000146  Allocation: RANDOMIZED|Intervention Model: |Ma...
# 1411  NCT03737851  Allocation: RANDOMIZED|Intervention Model: PAR...
# 1425  NCT03768648  Allocation: NON_RANDOMIZED|Intervention Model:...
# 1424  NCT03759522  Allocation: NON_RANDOMIZED|Intervention Model:...
# 1423  NCT03759249  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#       primary_purpose
# 0                   1
# 1411                1
# 1425                1
# 1424                1
# 1423                1

# %% [markdown]
# Yes; now join back to base dataframe.

# %% [markdown]
# ### Merge with base dataframe
# Note that we have to use two left joins separately, because we dropped NaNs along the way when exploding list fields.

# %%
ms_trials = pd.merge(left=ms_trials, right=design, on="nct_number", how="left")

# %%
ms_trials = pd.merge(
    left=ms_trials,
    right=primary_purpose[["nct_number", "primary_purpose"]],
    on="nct_number",
    how="left",
)

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  sex  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ALL
# 2     University Hospital, Toulouse                            NaN  ALL
# 3                     Klinik Valens                            NaN  ALL
# 4                     Klinik Valens                            NaN  ALL
#
#                   age  age_category  phases   phase  enrollment funder_type  \
# 0  ADULT, OLDER_ADULT         ADULT     NaN     NaN      1500.0       OTHER
# 1  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN      1500.0       OTHER
# 2               ADULT         ADULT  PHASE4  PHASE4       300.0       OTHER
# 3  ADULT, OLDER_ADULT         ADULT     NaN     NaN        30.0       OTHER
# 4  ADULT, OLDER_ADULT   OLDER_ADULT     NaN     NaN        30.0       OTHER
#
#        study_type                                       study_design  \
# 0   OBSERVATIONAL          Observational Model: |Time Perspective: p
# 1   OBSERVATIONAL          Observational Model: |Time Perspective: p
# 2  INTERVENTIONAL  Allocation: NA|Intervention Model: SINGLE_GROU...
# 3  INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
# 4  INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#   primary_purpose
# 0             NaN
# 1             NaN
# 2      DIAGNOSTIC
# 3       TREATMENT
# 4       TREATMENT

# %% [markdown]
# ## Dates

# %%
dates = raw_trial_data[
    ["nct_number", "Start Date", "Primary Completion Date", "Completion Date"]
].copy()

# %%
dates = dates.rename(
    columns={colname: colname.lower().replace(" ", "_") for colname in dates.columns}
)

# %%
dates
# Out:
#        nct_number  start_date primary_completion_date completion_date
# 0     NCT04447937  2020-06-29              2021-01-30      2021-07-30
# 1     NCT00942214     2009-06                 2011-02         2011-03
# 2     NCT05562414  2022-10-01              2023-04-01      2023-04-01
# 3     NCT05090033  2022-12-08              2025-06-30      2025-06-30
# 4     NCT00883337     2009-04                 2011-09         2015-05
# ...           ...         ...                     ...             ...
# 2959  NCT02451696     2014-01              2017-12-08      2017-12-28
# 2960  NCT01191996     2010-08                 2012-06         2012-11
# 2961  NCT03826095  2019-02-04              2019-07-26      2019-08-02
# 2962  NCT05341895  2021-11-22              2022-04-22      2022-05-06
# 2963  NCT03458169  2018-01-01              2018-04-30      2018-04-30
#
# [2964 rows x 4 columns]

# %% [markdown]
# Dates have different resolution; extract the year.

# %%
dates["start_year"] = dates["start_date"].str[:4]
dates["primary_completion_year"] = dates["primary_completion_date"].str[:4]
dates["completion_year"] = dates["completion_date"].str[:4]

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(left=ms_trials, right=dates, on="nct_number", how="left")

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  ...  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ...
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ...
# 2     University Hospital, Toulouse                            NaN  ...
# 3                     Klinik Valens                            NaN  ...
# 4                     Klinik Valens                            NaN  ...
#
#   funder_type      study_type  \
# 0       OTHER   OBSERVATIONAL
# 1       OTHER   OBSERVATIONAL
# 2       OTHER  INTERVENTIONAL
# 3       OTHER  INTERVENTIONAL
# 4       OTHER  INTERVENTIONAL
#
#                                         study_design primary_purpose  \
# 0          Observational Model: |Time Perspective: p             NaN
# 1          Observational Model: |Time Perspective: p             NaN
# 2  Allocation: NA|Intervention Model: SINGLE_GROU...      DIAGNOSTIC
# 3  Allocation: RANDOMIZED|Intervention Model: PAR...       TREATMENT
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...       TREATMENT
#
#    start_date  primary_completion_date completion_date start_year  \
# 0  2020-06-29               2021-01-30      2021-07-30       2020
# 1  2020-06-29               2021-01-30      2021-07-30       2020
# 2     2009-06                  2011-02         2011-03       2009
# 3  2022-10-01               2023-04-01      2023-04-01       2022
# 4  2022-10-01               2023-04-01      2023-04-01       2022
#
#   primary_completion_year completion_year
# 0                    2021            2021
# 1                    2021            2021
# 2                    2011            2011
# 3                    2023            2023
# 4                    2023            2023
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Locations
# Site locations are provided as pipe-separated list of addresses. We split the list, write each address on a separate row, then extract the country from the address.

# %%
locations = (
    raw_trial_data[["nct_number", "Locations"]]
    .rename(columns={"Locations": "locations"})
    .copy()
)

# %%
locations["location"] = locations["locations"].str.split("|")
locations = locations.explode("location")

# %%
locations
# Out:
#        nct_number                                          locations  \
# 0     NCT04447937  Advanced Neurosciences Institute, Franklin, Te...
# 1     NCT00942214  service de neurologie, hôpital Purpan, Toulous...
# 2     NCT05562414  Klinik Valens, Valens rehabilitation clinic, V...
# 3     NCT05090033  Novartis Investigative Site, Concord, New Sout...
# 3     NCT05090033  Novartis Investigative Site, Concord, New Sout...
# ...           ...                                                ...
# 2960  NCT01191996  Primorus Clinical Trials, 40 Stewart Street, C...
# 2961  NCT03826095               Hacettepe University, Ankara, Turkey
# 2962  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 2962  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 2963  NCT03458169  Clinique Romande de Réadaptation (CRR), SUVAca...
#
#                                                location
# 0     Advanced Neurosciences Institute, Franklin, Te...
# 1     service de neurologie, hôpital Purpan, Toulous...
# 2     Klinik Valens, Valens rehabilitation clinic, V...
# 3     Novartis Investigative Site, Concord, New Sout...
# 3     Novartis Investigative Site, Southport, Queens...
# ...                                                 ...
# 2960  Primorus Clinical Trials, 40 Stewart Street, C...
# 2961               Hacettepe University, Ankara, Turkey
# 2962                Furkan Bilek, Elazığ, 23100, Turkey
# 2962            Fırat university, Elazığ, 23100, Turkey
# 2963  Clinique Romande de Réadaptation (CRR), SUVAca...
#
# [33799 rows x 3 columns]

# %% [markdown]
# ### Get the country from the site address
# The address format is standardized as a comma separated list with the country name as last item. In some cases, the country name itself contains a comma (as in e.g. 'Iran, Islamic Republic of'). Thus, if an address ends with 'epublic of' (drop the 'r' so we don't have to adjust capitalization), we take the two last entries and re-order them.

# %%
def country_from_location(raw_location):
    raw_location = str(raw_location)
    if raw_location.endswith("epublic of"):
        country = reversed(raw_location.split(",")[-2:])
        country = "".join(country).strip()
    else:
        country = raw_location.split(",")[-1].strip()
    return country

# %%
locations["country"] = locations.apply(
    lambda row: country_from_location(raw_location=row["location"]), axis=1
)

# %%
locations
# Out:
#        nct_number                                          locations  \
# 0     NCT04447937  Advanced Neurosciences Institute, Franklin, Te...
# 1     NCT00942214  service de neurologie, hôpital Purpan, Toulous...
# 2     NCT05562414  Klinik Valens, Valens rehabilitation clinic, V...
# 3     NCT05090033  Novartis Investigative Site, Concord, New Sout...
# 3     NCT05090033  Novartis Investigative Site, Concord, New Sout...
# ...           ...                                                ...
# 2960  NCT01191996  Primorus Clinical Trials, 40 Stewart Street, C...
# 2961  NCT03826095               Hacettepe University, Ankara, Turkey
# 2962  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 2962  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 2963  NCT03458169  Clinique Romande de Réadaptation (CRR), SUVAca...
#
#                                                location        country
# 0     Advanced Neurosciences Institute, Franklin, Te...  United States
# 1     service de neurologie, hôpital Purpan, Toulous...         France
# 2     Klinik Valens, Valens rehabilitation clinic, V...    Switzerland
# 3     Novartis Investigative Site, Concord, New Sout...      Australia
# 3     Novartis Investigative Site, Southport, Queens...      Australia
# ...                                                 ...            ...
# 2960  Primorus Clinical Trials, 40 Stewart Street, C...    New Zealand
# 2961               Hacettepe University, Ankara, Turkey         Turkey
# 2962                Furkan Bilek, Elazığ, 23100, Turkey         Turkey
# 2962            Fırat university, Elazığ, 23100, Turkey         Turkey
# 2963  Clinique Romande de Réadaptation (CRR), SUVAca...    Switzerland
#
# [33799 rows x 4 columns]

# %% [markdown]
# ### Check 'Many Locations'
# Some locations are not given explicitly; can these 'many location' data be mixed with specific addresses?

# %%
locations[locations["location"].astype(str).str.startswith("Many Locations")]
# Out:
#        nct_number                                          locations  \
# 69    NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69    NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69    NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69    NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69    NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# ...           ...                                                ...
# 2956  NCT00461396  Many Locations, Alabama, United States|Many Lo...
# 2956  NCT00461396  Many Locations, Alabama, United States|Many Lo...
# 2956  NCT00461396  Many Locations, Alabama, United States|Many Lo...
# 2956  NCT00461396  Many Locations, Alabama, United States|Many Lo...
# 2956  NCT00461396  Many Locations, Alabama, United States|Many Lo...
#
#                                            location        country
# 69                          Many Locations, Austria        Austria
# 69                          Many Locations, Belgium        Belgium
# 69                          Many Locations, Finland        Finland
# 69                          Many Locations, Germany        Germany
# 69                           Many Locations, Israel         Israel
# ...                                             ...            ...
# 2956  Many Locations, North Carolina, United States  United States
# 2956            Many Locations, Ohio, United States  United States
# 2956    Many Locations, Pennsylvania, United States  United States
# 2956       Many Locations, Tennessee, United States  United States
# 2956   Many Locations, West Virginia, United States  United States
#
# [175 rows x 4 columns]

# %%
locations[
    (~locations["location"].astype(str).str.startswith("Many Locations"))
    & (locations["location"].astype(str).str.contains("Many Locations"))
]
# Out:
# Empty DataFrame
# Columns: [nct_number, locations, location, country]
# Index: []

# %% [markdown]
# -> if a trial indicates 'Many locations', the site information always starts with 'Many locations' (i.e. never an address, then 'many locations').

# %% [markdown]
# ### Flag entries with 'Many Locations'

# %%
locations["many_locations_flag"] = (
    locations["location"].astype(str).str.lower().str.startswith("many locations")
)

# %%
locations[locations["many_locations_flag"]].head()
# Out:
#      nct_number                                          locations  \
# 69  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 69  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
#
#                    location  country  many_locations_flag
# 69  Many Locations, Austria  Austria                 True
# 69  Many Locations, Belgium  Belgium                 True
# 69  Many Locations, Finland  Finland                 True
# 69  Many Locations, Germany  Germany                 True
# 69   Many Locations, Israel   Israel                 True

# %%
len(locations[locations["many_locations_flag"]])
# Out:
# 189

# %% [markdown]
# ### Add country ISO codes and continents
# We manually created a mapping of country names and their corresponding 3-character ISO code.

# %%
country_mapping = pd.read_excel("data/manual/clinicaltrials//countries.xlsx")

# %%
locations = pd.merge(
    left=locations, right=country_mapping, on="country", how="left"
)

# %%
locations
# Out:
#         nct_number                                          locations  \
# 0      NCT04447937  Advanced Neurosciences Institute, Franklin, Te...
# 1      NCT00942214  service de neurologie, hôpital Purpan, Toulous...
# 2      NCT05562414  Klinik Valens, Valens rehabilitation clinic, V...
# 3      NCT05090033  Novartis Investigative Site, Concord, New Sout...
# 4      NCT05090033  Novartis Investigative Site, Concord, New Sout...
# ...            ...                                                ...
# 33794  NCT01191996  Primorus Clinical Trials, 40 Stewart Street, C...
# 33795  NCT03826095               Hacettepe University, Ankara, Turkey
# 33796  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 33797  NCT05341895  Furkan Bilek, Elazığ, 23100, Turkey|Fırat univ...
# 33798  NCT03458169  Clinique Romande de Réadaptation (CRR), SUVAca...
#
#                                                 location        country  \
# 0      Advanced Neurosciences Institute, Franklin, Te...  United States
# 1      service de neurologie, hôpital Purpan, Toulous...         France
# 2      Klinik Valens, Valens rehabilitation clinic, V...    Switzerland
# 3      Novartis Investigative Site, Concord, New Sout...      Australia
# 4      Novartis Investigative Site, Southport, Queens...      Australia
# ...                                                  ...            ...
# 33794  Primorus Clinical Trials, 40 Stewart Street, C...    New Zealand
# 33795               Hacettepe University, Ankara, Turkey         Turkey
# 33796                Furkan Bilek, Elazığ, 23100, Turkey         Turkey
# 33797            Fırat university, Elazığ, 23100, Turkey         Turkey
# 33798  Clinique Romande de Réadaptation (CRR), SUVAca...    Switzerland
#
#        many_locations_flag   country_norm country_ISO country_continent
# 0                    False  United States         USA     North America
# 1                    False         France         FRA            Europe
# 2                    False    Switzerland         CHE            Europe
# 3                    False      Australia         AUS           Oceania
# 4                    False      Australia         AUS           Oceania
# ...                    ...            ...         ...               ...
# 33794                False    New Zealand         NZL           Oceania
# 33795                False         Turkey         TUR              Asia
# 33796                False         Turkey         TUR              Asia
# 33797                False         Turkey         TUR              Asia
# 33798                False    Switzerland         CHE            Europe
#
# [33799 rows x 8 columns]

# %% [markdown]
# Is the country missing for any entry with a valid location?

# %%
locations[(locations["country_ISO"].isna()) & (~locations["location"].isna())]
# Out:
# Empty DataFrame
# Columns: [nct_number, locations, location, country, many_locations_flag, country_norm, country_ISO, country_continent]
# Index: []

# %% [markdown]
# All locations properly matched.

# %% [markdown]
# ### Compute the number of sites per country
# Instead of listing all sites for the same country, we just keep the number of sites.

# %%
sites_per_trial_per_country = (
    locations.drop(columns=["location"])
    .groupby(
        [
            "nct_number",
            "locations",
            "many_locations_flag",
            "country_norm",
            "country_ISO",
            "country_continent",
        ],
        as_index=False,
    )
    .size()
    .rename(columns={"size": "n_sites"})
)

# %%
sites_per_trial_per_country
# Out:
#        nct_number                                          locations  \
# 0     NCT00000146  University of Arkansas, Little Rock, Arkansas,...
# 1     NCT00000147  University of Arkansas, Little Rock, Arkansas,...
# 2     NCT00001156  National Institutes of Health Clinical Center,...
# 3     NCT00001248  National Institutes of Health Clinical Center,...
# 4     NCT00001465  National Institutes of Health Clinical Center,...
# ...           ...                                                ...
# 6449  NCT05840653                      SAMSUN, Samsun, 55000, Turkey
# 6450  NCT05844826  University of Calgary, Calgary, Alberta, T2N 1...
# 6451  NCT05849467  National Institutes of Health Clinical Center,...
# 6452  NCT05853835                  Triumpharma, Amman, 11941, Jordan
# 6453  NCT05857280              SSMC, Abu Dhabi, United Arab Emirates
#
#       many_locations_flag          country_norm country_ISO country_continent  \
# 0                   False         United States         USA     North America
# 1                   False         United States         USA     North America
# 2                   False         United States         USA     North America
# 3                   False         United States         USA     North America
# 4                   False         United States         USA     North America
# ...                   ...                   ...         ...               ...
# 6449                False                Turkey         TUR              Asia
# 6450                False                Canada         CAN     North America
# 6451                False         United States         USA     North America
# 6452                False                Jordan         JOR              Asia
# 6453                False  United Arab Emirates         ARE              Asia
#
#       n_sites
# 0          15
# 1          15
# 2           1
# 3           1
# 4           1
# ...       ...
# 6449        1
# 6450        1
# 6451        1
# 6452        1
# 6453        1
#
# [6454 rows x 7 columns]

# %% [markdown]
# **Note**: If 'many locations', then the site count is 1!

# %%
sites_per_trial_per_country[sites_per_trial_per_country["nct_number"] == "NCT00963833"]
# Out:
#        nct_number                                          locations  \
# 1464  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 1465  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 1466  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 1467  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 1468  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
# 1469  NCT00963833  Many Locations, Austria|Many Locations, Belgiu...
#
#       many_locations_flag    country_norm country_ISO country_continent  \
# 1464                 True         Austria         AUT            Europe
# 1465                 True         Belgium         BEL            Europe
# 1466                 True         Finland         FIN            Europe
# 1467                 True         Germany         DEU            Europe
# 1468                 True          Israel         ISR              Asia
# 1469                 True  United Kingdom         GBR            Europe
#
#       n_sites
# 1464        1
# 1465        1
# 1466        1
# 1467        1
# 1468        1
# 1469        1

# %% [markdown]
# ### Merge with base dataframe

# %%
ms_trials = pd.merge(
    left=ms_trials, right=sites_per_trial_per_country, on="nct_number", how="left"
)

# %%
ms_trials.head()
# Out:
#     nct_number                                        study_title  \
# 0  NCT04447937                             Immunodeficiency in MS
# 1  NCT04447937                             Immunodeficiency in MS
# 2  NCT00942214  Biomarkers and Response to Natalizumab for Mul...
# 3  NCT05562414  Transient and Immediate Motor Effects of Exerc...
# 4  NCT05562414  Transient and Immediate Motor Effects of Exerc...
#
#                                            study_url study_status  \
# 0  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 1  https://beta.clinicaltrials.gov/study/NCT04447937      UNKNOWN
# 2  https://beta.clinicaltrials.gov/study/NCT00942214    COMPLETED
# 3  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
# 4  https://beta.clinicaltrials.gov/study/NCT05562414   RECRUITING
#
#                                           conditions condition_category  \
# 0  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 1  Multiple Sclerosis|Hypogammaglobulinemia|Immun...                 MS
# 2                                 Multiple Sclerosis                 MS
# 3  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
# 4  Multiple Sclerosis, Chronic Progressive|High-I...                PMS
#
#                       interventions intervention_type  \
# 0           OTHER: No Interventions             OTHER
# 1           OTHER: No Interventions             OTHER
# 2                 DRUG: Natalizumab              DRUG
# 3  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
# 4  BEHAVIORAL: HIIT|BEHAVIORAL: MCT        BEHAVIORAL
#
#                             sponsor                  collaborators  ...  \
# 0  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ...
# 1  Advanced Neurosciences Institute  Novel Pharmaceutics Institute  ...
# 2     University Hospital, Toulouse                            NaN  ...
# 3                     Klinik Valens                            NaN  ...
# 4                     Klinik Valens                            NaN  ...
#
#   completion_date start_year primary_completion_year completion_year  \
# 0      2021-07-30       2020                    2021            2021
# 1      2021-07-30       2020                    2021            2021
# 2         2011-03       2009                    2011            2011
# 3      2023-04-01       2022                    2023            2023
# 4      2023-04-01       2022                    2023            2023
#
#                                            locations  many_locations_flag  \
# 0  Advanced Neurosciences Institute, Franklin, Te...                False
# 1  Advanced Neurosciences Institute, Franklin, Te...                False
# 2  service de neurologie, hôpital Purpan, Toulous...                False
# 3  Klinik Valens, Valens rehabilitation clinic, V...                False
# 4  Klinik Valens, Valens rehabilitation clinic, V...                False
#
#     country_norm country_ISO country_continent n_sites
# 0  United States         USA     North America     1.0
# 1  United States         USA     North America     1.0
# 2         France         FRA            Europe     1.0
# 3    Switzerland         CHE            Europe     1.0
# 4    Switzerland         CHE            Europe     1.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Export

# %%
len(ms_trials), len(ms_trials.drop_duplicates()), len(ms_trials["nct_number"].drop_duplicates())
# Out:
# (11705, 11705, 2711)

# %%
# safety switch
polse

# %%
with pd.ExcelWriter("data/intermediate/ms_trials_long.xlsx") as writer:
    ms_trials.to_excel(writer, index=False)
